# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as act

# %%
#couvert the data into a data frame
df = pd.read_csv("data-69d3709338fdb705334215.csv")
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced   84835.0        0
# 1         1        1961  Graduation         Single   57091.0        0
# 2     10476        1958  Graduation        Married   67267.0        0
# 3      1386        1967  Graduation       Together   32474.0        1
# 4      5371        1989  Graduation         Single   21474.0        1
# ...     ...         ...         ...            ...       ...      ...
# 2235  10142        1976         PhD       Divorced   66476.0        0
# 2236   5263        1977    2n Cycle        Married   31056.0        1
# 2237     22        1976  Graduation       Divorced   46310.0        1
# 2238    528        1978  Graduation        Married   65819.0        0
# 2239   4070        1969         PhD        Married   94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
total = df['MntBakedProds']

# %%
#analyse the variable "Education"
df['Education'].value_counts()
# Out:
# Education
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
# a bar chart for this variable
plt.figure(figsize=(11,5))
df['Education'].value_counts().plot.bar()
plt.title("deff education count", c = 'k', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'deff education count')

# %%
#analyse the variable income
df[' Income '].describe()
# Out:
# count      2216.000000
# mean      52247.251354
# std       25173.076661
# min        1730.000000
# 25%       35303.000000
# 50%       51381.500000
# 75%       68522.000000
# max      666666.000000
# Name:  Income , dtype: float64

# %%
df[' Income '].sum()
# Out:
# np.float64(115779909.0)

# %%
plt.figure(figsize=(11,5))
sns.histplot(data = df, x = df[' Income '])
plt.title("description of income values", c = 'k', fontsize = 26)
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
plt.figure(figsize=(11,5))
sns.boxplot(data = df, x = df[' Income '])
# Out:
# <Axes: xlabel=' Income '>

# %%
#analyse the variable country
df['Country'].value_counts()
# Out:
# Country
# Spain           1095
# Saudi Arabia     337
# Canada           268
# Australia        160
# India            148
# Germany          120
# USA              109
# Mexico             3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(11,5))
df['Country'].value_counts().plot.bar()
plt.title("count of customers by country", c = 'k', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'count of customers by country')

# %% [markdown]
# Bar charts for the number of customers who accepted each campaign.

# %%
# Melt the data to long format

df_melted = df.melt(value_vars=['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5'], 
                    var_name='Campaign', value_name='Accepted')

plt.figure(figsize=(12, 6))
sns.countplot(data=df_melted, x='Campaign', hue='Accepted')
plt.title('Campaign Acceptance Comparison (0 vs 1)')
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
plt.figure(figsize=(14, 5))
matrix = df[['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5']].corr()

sns.heatmap(matrix, cmap = 'coolwarm', fmt = '.2f', annot = True)
# Out:
# <Axes: >

# %% [markdown]
# TOTAL SALES FOR EVERY COUNTRY

# %%
plt.figure(figsize=(11,5))
sns.barplot(data = df, x = df['Country'], y = df[' Income '], errorbar= None, color ='#EFBF04')
plt.title("yearly income by country", c = 'k', fontsize = 20)
plt.xlabel("Countrys")
# Out:
# Text(0.5, 0, 'Countrys')

# %%
plt.figure(figsize=(18,8))
plt.title("")
filter_nb = df.select_dtypes(include= 'number')
sns.heatmap (filter_nb.corr(), cmap = 'coolwarm' ,fmt=".2f", annot= True)
# Out:
# <Axes: >

# %% [markdown]
# Check for anomalies, missing values ​​and duplicates.

# %%
#cheak for messing values
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
#  Income                24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntBakedProds           0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
#cheak for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
total_spent = df[fd['']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\oussama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ...
